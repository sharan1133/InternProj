# %%
import pandas as pd

import matplotlib.pyplot as plt

import seaborn as sns

# %%
df = pd.read_csv('/home/sharanbalakrishnan/Desktop/InternProj/data_dash.csv')

# %%
df
# Out:
#       Unnamed: 0.1  Unnamed: 0         Ram    Storage   Brand   Color
# 0                0           0   4 GB RAM   64 GB ROM  realme    Blue  \
# 1                1           1   6 GB RAM   128 GB RO  realme   Black
# 2                2           2   8 GB RAM   128 GB RO  realme    Blue
# 3                3           3   8 GB RAM   256 GB RO  realme    Blue
# 4                4           5   4 GB RAM   64 GB ROM  realme   Black
# ...            ...         ...         ...        ...     ...     ...
# 1037          1037        1838   4 GB RAM   64 GB ROM   redmi    Grey
# 1038          1038        1843  12 GB RAM   256 GB RO    vivo   Black
# 1039          1039        1845   6 GB RAM   128 GB RO    oppo  Silver
# 1040          1040        1846   4 GB RAM   64 GB ROM   redmi    Blue
# 1041          1041        1849   8 GB RAM   256 GB RO    vivo    Blue
#
#       Display_Size Display_Type  Front_Cam  Rear_Cam  Price
# 0             6.50          HD+          5        50   9999
# 1             6.60          HD+         16        50  13499
# 2             6.70          HD+         16       108  25999
# 3             6.70          HD+         16       108  27999
# 4             6.60          HD+          8        50  14999
# ...            ...          ...        ...       ...    ...
# 1037          6.53          HD+         13        48  14999
# 1038          6.43       AMOLED         50        50  36999
# 1039          6.43          HD+         16        48  14990
# 1040          6.53          HD+          5        13   7699
# 1041          6.44          HD+         44        64  30990
#
# [1042 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1042 entries, 0 to 1041
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    1042 non-null   int64
#  1   Model         1042 non-null   object
#  2   Ram           1042 non-null   object
#  3   Storage       1042 non-null   object
#  4   Display       1042 non-null   object
#  5   Camera        1042 non-null   object
#  6   Battery       1042 non-null   object
#  7   Price         1042 non-null   object
#  8   Brand         1042 non-null   object
#  9   Color         1042 non-null   object
#  10  Display_Size  1042 non-null   float64
#  11  Display_Type  1042 non-null   object
#  12  Front_Cam     1042 non-null   int64
#  13  Rear_Cam      1042 non-null   int64
# dtypes: float64(1), int64(3), object(10)
# memory usage: 114.1+ KB

# %%
df
# Out:
#       Unnamed: 0         Ram    Storage   Brand   Color  Display_Size  \
# 0              0   4 GB RAM   64 GB ROM  realme    Blue          6.50
# 1              1   6 GB RAM   128 GB RO  realme   Black          6.60
# 2              2   8 GB RAM   128 GB RO  realme    Blue          6.70
# 3              3   8 GB RAM   256 GB RO  realme    Blue          6.70
# 4              5   4 GB RAM   64 GB ROM  realme   Black          6.60
# ...          ...         ...        ...     ...     ...           ...
# 1037        1838   4 GB RAM   64 GB ROM   redmi    Grey          6.53
# 1038        1843  12 GB RAM   256 GB RO    vivo   Black          6.43
# 1039        1845   6 GB RAM   128 GB RO    oppo  Silver          6.43
# 1040        1846   4 GB RAM   64 GB ROM   redmi    Blue          6.53
# 1041        1849   8 GB RAM   256 GB RO    vivo    Blue          6.44
#
#      Display_Type  Front_Cam  Rear_Cam    Price
# 0             HD+          5        50   ₹9,999
# 1             HD+         16        50  ₹13,499
# 2             HD+         16       108  ₹25,999
# 3             HD+         16       108  ₹27,999
# 4             HD+          8        50  ₹14,999
# ...           ...        ...       ...      ...
# 1037          HD+         13        48  ₹14,999
# 1038       AMOLED         50        50  ₹36,999
# 1039          HD+         16        48  ₹14,990
# 1040          HD+          5        13   ₹7,699
# 1041          HD+         44        64  ₹30,990
#
# [1042 rows x 10 columns]

# %%
df['Price'] = df['Price'].str.replace('₹', '').str.replace(',', '')

# %%
df.to_csv('data_dash.csv')

# %%
df['Color'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: >

# %%
df['Brand'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Brand'>

# %%
df['Ram'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Ram'>

# %%
df['Storage'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Storage'>

# %%
# Out:
#       Unnamed: 0         Ram    Storage   Brand   Color  Display_Size
# 0              0   4 GB RAM   64 GB ROM  realme    Blue          6.50  \
# 1              1   6 GB RAM   128 GB RO  realme   Black          6.60
# 2              2   8 GB RAM   128 GB RO  realme    Blue          6.70
# 3              3   8 GB RAM   256 GB RO  realme    Blue          6.70
# 4              5   4 GB RAM   64 GB ROM  realme   Black          6.60
# ...          ...         ...        ...     ...     ...           ...
# 1037        1838   4 GB RAM   64 GB ROM   redmi    Grey          6.53
# 1038        1843  12 GB RAM   256 GB RO    vivo   Black          6.43
# 1039        1845   6 GB RAM   128 GB RO    oppo  Silver          6.43
# 1040        1846   4 GB RAM   64 GB ROM   redmi    Blue          6.53
# 1041        1849   8 GB RAM   256 GB RO    vivo    Blue          6.44
#
#      Display_Type  Front_Cam  Rear_Cam    Price
# 0             HD+          5        50   ₹9,999
# 1             HD+         16        50  ₹13,499
# 2             HD+         16       108  ₹25,999
# 3             HD+         16       108  ₹27,999
# 4             HD+          8        50  ₹14,999
# ...           ...        ...       ...      ...
# 1037          HD+         13        48  ₹14,999
# 1038       AMOLED         50        50  ₹36,999
# 1039          HD+         16        48  ₹14,990
# 1040          HD+          5        13   ₹7,699
# 1041          HD+         44        64  ₹30,990
#
# [1042 rows x 10 columns]
